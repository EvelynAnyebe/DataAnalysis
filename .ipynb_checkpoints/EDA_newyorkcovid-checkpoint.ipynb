# %% [markdown]
# ## Exploratory Data Analysis(EDA) With Python
#
# Data analytics is concerned with examining,transforming and arranging raw data so that we can study, extract meaningful information and make inferences from it. Data analytics is a broad field that combines statistics, computer science and domain knowledge such as business knowledge to reach a goal. An easy way to understand data analytics is by examining its types. There are five(5) types of data analytics:
#
# - Descriptive concerned with determining what happened
# - Diagonistic explains why things happen
# - Predictive tries to show us what will happen in the future
# - Prescriptive give insights on what actions should be taken to achieve a target
# - Cognitive concerned with mimicking human cognitive capabilities such as self-learning, automatic decison making among others using data.
#
# A data analysis task may involve more than one of these types and is not limited to a particular goal. Sometimes, a data analysts may need guidiance in choosing the goal or target for the problem. **Exploratory data analysis(EDA)** involves understanding your dataset before deciding how best to manipulate it to get the answers you want.
#
# EDA is used investigate the dataset and summarize their main characteristics. It shows what the data can reveal beyond the formal hypothesis testing task and provides a better understanding of the dataset variables and the relationship between them. It can help data analysts determine the best statistical techniques to use. EDA helps stakeholders by confirming they are asking the right questions. Once EDA is complete, its insight can then be used for further data analysis.

# %% [markdown]
# ### Preparations
#
# Python is an interpreted, object oriented programming language with dynamic typing and dynamic binding for rapid application development. It can be used as a scritpting language and has a rich set of open source libraries for data analysis. For example Pandas, Matplotlib, numpy among others. Having a good knowledge of the libraries will enable you understand this notebook. A great book for this is [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/)
#
# To begin, We import the needed library.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#sets the backend of matplotlib to the inline backend
# %matplotlib inline 

#Use style that emulates R ggplot aesthetics 
plt.style.use('ggplot')

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# ### Load the dataset
#
# Nothing can be done as a data analyst without having any data. In this instance, a dataset of covid-19 cases in New York is avaliable as a CSV file for our use. In some cases a data analyst is required to identify all the available dataset of the company and extract it into a usable format. At this point skills for working with data management systems are needed. These include knowledge of DBMS (MYSQL, MongoDB etc), Querying databases, retrieving unstructured data, distributed storage(Hadoop, Apache spark etc) among others.
#
# **Pandas** is a popular package for data science that offers powerful and flexible data structures for holding data in memory. A dataset loaded into Pandas is primarily stored as a dataframe. A DataFrame is two dimensional labeled data structure with columns of different data types. It is made up of three parts: index, columns and data. A one-dimensional labeled array capable of any data type with axis or index is called a pandas series.

# %%
df=pd.read_csv("new-york-history.csv") #loads the data

##View the some recrods in the data set
df.head()
# Out:
#          date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0  2021-03-01    NY  38577.0             NaN             80            NaN
# 1  2021-02-28    NY  38497.0             NaN             90            NaN
# 2  2021-02-27    NY  38407.0             NaN             86            NaN
# 3  2021-02-26    NY  38321.0             NaN             94            NaN
# 4  2021-02-25    NY  38227.0             NaN             92            NaN
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0       89995.0                 89995.0                 5307.0
# 1       89995.0                 89995.0                 5259.0
# 2       89995.0                 89995.0                 5445.0
# 3       89995.0                 89995.0                 5626.0
# 4       89995.0                 89995.0                 5703.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# 0                     0  ...          38281073                    174158
# 1                     0  ...          38106915                    273720
# 2                     0  ...          37833195                    285307
# 3                     0  ...          37547888                    291189
# 4                     0  ...          37256699                    278942
#
#    totalTestsAntibody  totalTestsAntigen  totalTestsPeopleAntibody  \
# 0                 NaN                NaN                       NaN
# 1                 NaN                NaN                       NaN
# 2                 NaN                NaN                       NaN
# 3                 NaN                NaN                       NaN
# 4                 NaN                NaN                       NaN
#
#    totalTestsPeopleAntigen  totalTestsPeopleViral  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
#
#    totalTestsPeopleViralIncrease  totalTestsViral  totalTestsViralIncrease
# 0                              0              NaN                        0
# 1                              0              NaN                        0
# 2                              0              NaN                        0
# 3                              0              NaN                        0
# 4                              0              NaN                        0
#
# [5 rows x 41 columns]

# %% [markdown]
# A view of the first 5 rows in the data shows us the column names and type of values in the data. This is a basic data exploration - seeing the values in your dataset and knowing the column names. From the table of a few records, there exist many records with NaNs. This tell says the data must cleaned before analysis. The dataset has many columns and intuitively, there is a question about the relevant features. The presence of date column also give insight that a better way to approach this dataset is by analysing trends.
#
# First, get more details about Null values in the dataset.

# %%
df.info() #Give us more information about individual columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date                              365 non-null    object
#  1   state                             365 non-null    object
#  2   death                             352 non-null    float64
#  3   deathConfirmed                    1 non-null      float64
#  4   deathIncrease                     365 non-null    int64
#  5   deathProbable                     0 non-null      float64
#  6   hospitalized                      346 non-null    float64
#  7   hospitalizedCumulative            346 non-null    float64
#  8   hospitalizedCurrently             350 non-null    float64
#  9   hospitalizedIncrease              365 non-null    int64
#  10  inIcuCumulative                   0 non-null      float64
#  11  inIcuCurrently                    341 non-null    float64
#  12  negative                          0 non-null      float64
#  13  negativeIncrease                  365 non-null    int64
#  14  negativeTestsAntibody             0 non-null      float64
#  15  negativeTestsPeopleAntibody       0 non-null      float64
#  16  negativeTestsViral                0 non-null      float64
#  17  onVentilatorCumulative            0 non-null      float64
#  18  onVentilatorCurrently             299 non-null    float64
#  19  positive                          365 non-null    int64
#  20  positiveCasesViral                0 non-null      float64
#  21  positiveIncrease                  365 non-null    int64
#  22  positiveScore                     365 non-null    int64
#  23  positiveTestsAntibody             0 non-null      float64
#  24  positiveTestsAntigen              0 non-null      float64
#  25  positiveTestsPeopleAntibody       0 non-null      float64
#  26  positiveTestsPeopleAntigen        0 non-null      float64
#  27  positiveTestsViral                0 non-null      float64
#  28  recovered                         0 non-null      float64
#  29  totalTestEncountersViral          365 non-null    int64
#  30  totalTestEncountersViralIncrease  365 non-null    int64
#  31  totalTestResults                  365 non-null    int64
#  32  totalTestResultsIncrease          365 non-null    int64
#  33  totalTestsAntibody                0 non-null      float64
#  34  totalTestsAntigen                 0 non-null      float64
#  35  totalTestsPeopleAntibody          0 non-null      float64
#  36  totalTestsPeopleAntigen           0 non-null      float64
#  37  totalTestsPeopleViral             0 non-null      float64
#  38  totalTestsPeopleViralIncrease     365 non-null    int64
#  39  totalTestsViral                   0 non-null      float64
#  40  totalTestsViralIncrease           365 non-null    int64
# dtypes: float64(27), int64(12), object(2)
# memory usage: 117.0+ KB

# %% [markdown]
# ### Data Cleaning
# Data cleaning is the process of transforming your dataset to be fit for data analysis. It involves throwing away, replacing and/or filling missing valuse/errors. During data exploration, errors, missing values and/or currupt records present in the data are identified. For instance, only 15 columns have complete 365 data and the rest have NaN values. Some columns have about 70-95%, 50-69% of the total number of rows. Other contain items between 30% to 0% of the total number of records. We can decide to use just 15 columns with complete records or chose a valid percentage cut off for number of records and drop columns that do not reach the threshold. The latter option is employed here.
#
# Also, notice that the data contains date column of data type object. The date column should be converted into a datetime type for easy usage during visualization. This can be done by using the parse_date parameter of read_csv() or using pd.to_datetime.

# %%
df.date=df['date'].apply(lambda _: pd.to_datetime(_, format='%Y/%m/%d'))

# %%
df2 = pd.read_csv("new-york-history.csv",
                  parse_dates=['date'], index_col=['date'])
df2.head()
# Out:
#            state    death  deathConfirmed  deathIncrease  deathProbable  \
# date
# 2021-03-01    NY  38577.0             NaN             80            NaN
# 2021-02-28    NY  38497.0             NaN             90            NaN
# 2021-02-27    NY  38407.0             NaN             86            NaN
# 2021-02-26    NY  38321.0             NaN             94            NaN
# 2021-02-25    NY  38227.0             NaN             92            NaN
#
#             hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# date
# 2021-03-01       89995.0                 89995.0                 5307.0
# 2021-02-28       89995.0                 89995.0                 5259.0
# 2021-02-27       89995.0                 89995.0                 5445.0
# 2021-02-26       89995.0                 89995.0                 5626.0
# 2021-02-25       89995.0                 89995.0                 5703.0
#
#             hospitalizedIncrease  inIcuCumulative  ...  totalTestResults  \
# date                                               ...
# 2021-03-01                     0              NaN  ...          38281073
# 2021-02-28                     0              NaN  ...          38106915
# 2021-02-27                     0              NaN  ...          37833195
# 2021-02-26                     0              NaN  ...          37547888
# 2021-02-25                     0              NaN  ...          37256699
#
#             totalTestResultsIncrease  totalTestsAntibody  totalTestsAntigen  \
# date
# 2021-03-01                    174158                 NaN                NaN
# 2021-02-28                    273720                 NaN                NaN
# 2021-02-27                    285307                 NaN                NaN
# 2021-02-26                    291189                 NaN                NaN
# 2021-02-25                    278942                 NaN                NaN
#
#             totalTestsPeopleAntibody  totalTestsPeopleAntigen  \
# date
# 2021-03-01                       NaN                      NaN
# 2021-02-28                       NaN                      NaN
# 2021-02-27                       NaN                      NaN
# 2021-02-26                       NaN                      NaN
# 2021-02-25                       NaN                      NaN
#
#             totalTestsPeopleViral  totalTestsPeopleViralIncrease  \
# date
# 2021-03-01                    NaN                              0
# 2021-02-28                    NaN                              0
# 2021-02-27                    NaN                              0
# 2021-02-26                    NaN                              0
# 2021-02-25                    NaN                              0
#
#             totalTestsViral  totalTestsViralIncrease
# date
# 2021-03-01              NaN                        0
# 2021-02-28              NaN                        0
# 2021-02-27              NaN                        0
# 2021-02-26              NaN                        0
# 2021-02-25              NaN                        0
#
# [5 rows x 40 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2021-03-01 to 2020-03-02
# Data columns (total 40 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   state                             365 non-null    object
#  1   death                             352 non-null    float64
#  2   deathConfirmed                    1 non-null      float64
#  3   deathIncrease                     365 non-null    int64
#  4   deathProbable                     0 non-null      float64
#  5   hospitalized                      346 non-null    float64
#  6   hospitalizedCumulative            346 non-null    float64
#  7   hospitalizedCurrently             350 non-null    float64
#  8   hospitalizedIncrease              365 non-null    int64
#  9   inIcuCumulative                   0 non-null      float64
#  10  inIcuCurrently                    341 non-null    float64
#  11  negative                          0 non-null      float64
#  12  negativeIncrease                  365 non-null    int64
#  13  negativeTestsAntibody             0 non-null      float64
#  14  negativeTestsPeopleAntibody       0 non-null      float64
#  15  negativeTestsViral                0 non-null      float64
#  16  onVentilatorCumulative            0 non-null      float64
#  17  onVentilatorCurrently             299 non-null    float64
#  18  positive                          365 non-null    int64
#  19  positiveCasesViral                0 non-null      float64
#  20  positiveIncrease                  365 non-null    int64
#  21  positiveScore                     365 non-null    int64
#  22  positiveTestsAntibody             0 non-null      float64
#  23  positiveTestsAntigen              0 non-null      float64
#  24  positiveTestsPeopleAntibody       0 non-null      float64
#  25  positiveTestsPeopleAntigen        0 non-null      float64
#  26  positiveTestsViral                0 non-null      float64
#  27  recovered                         0 non-null      float64
#  28  totalTestEncountersViral          365 non-null    int64
#  29  totalTestEncountersViralIncrease  365 non-null    int64
#  30  totalTestResults                  365 non-null    int64
#  31  totalTestResultsIncrease          365 non-null    int64
#  32  totalTestsAntibody                0 non-null      float64
#  33  totalTestsAntigen                 0 non-null      float64
#  34  totalTestsPeopleAntibody          0 non-null      float64
#  35  totalTestsPeopleAntigen           0 non-null      float64
#  36  totalTestsPeopleViral             0 non-null      float64
#  37  totalTestsPeopleViralIncrease     365 non-null    int64
#  38  totalTestsViral                   0 non-null      float64
#  39  totalTestsViralIncrease           365 non-null    int64
# dtypes: float64(27), int64(12), object(1)
# memory usage: 116.9+ KB

# %%
df3 = df2[[column for column in df2 if df2[column].count()/len(df2)>=0.3]]
#This uses list comprehension to remove columns that have less not null values than 30% of the total number of rows.
#count() method does not count null values

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2021-03-01 to 2020-03-02
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   state                             365 non-null    object
#  1   death                             352 non-null    float64
#  2   deathIncrease                     365 non-null    int64
#  3   hospitalized                      346 non-null    float64
#  4   hospitalizedCumulative            346 non-null    float64
#  5   hospitalizedCurrently             350 non-null    float64
#  6   hospitalizedIncrease              365 non-null    int64
#  7   inIcuCurrently                    341 non-null    float64
#  8   negativeIncrease                  365 non-null    int64
#  9   onVentilatorCurrently             299 non-null    float64
#  10  positive                          365 non-null    int64
#  11  positiveIncrease                  365 non-null    int64
#  12  positiveScore                     365 non-null    int64
#  13  totalTestEncountersViral          365 non-null    int64
#  14  totalTestEncountersViralIncrease  365 non-null    int64
#  15  totalTestResults                  365 non-null    int64
#  16  totalTestResultsIncrease          365 non-null    int64
#  17  totalTestsPeopleViralIncrease     365 non-null    int64
#  18  totalTestsViralIncrease           365 non-null    int64
# dtypes: float64(6), int64(12), object(1)
# memory usage: 57.0+ KB

# %% [markdown]
# These are the relevant features that can provide insight on Covid-19 pandemic in Newyork. At this point, records with NaNs will be dropped to provide an even dataset to work with.

# %%
df3=df3.dropna() #drop all rows with null values

#display the size of the dataframe 
df3.shape
# Out:
# (299, 19)

# %% [markdown]
# ### Exploration of the data
# Here, the cleaned dataset is investigated to gain further understanding of each feature in it.

# %%
df3.describe() #this gives basic statistics information on each feature of the dataset
# Out:
#               death  deathIncrease  hospitalized  hospitalizedCumulative  \
# count    299.000000     299.000000    299.000000              299.000000
# mean   27321.672241      62.541806  89714.498328            89714.498328
# std     4166.191740      80.328859   1121.875286             1121.875286
# min    20828.000000       1.000000  82197.000000            82197.000000
# 25%    25057.000000       8.500000  89995.000000            89995.000000
# 50%    25505.000000      27.000000  89995.000000            89995.000000
# 75%    28161.000000     112.000000  89995.000000            89995.000000
# max    38577.000000     951.000000  89995.000000            89995.000000
#
#        hospitalizedCurrently  hospitalizedIncrease  inIcuCurrently  \
# count             299.000000            299.000000      299.000000
# mean             3290.337793             28.177258      700.337793
# std              3014.864131             98.373102      632.156475
# min               410.000000              0.000000      109.000000
# 25%               705.500000              0.000000      159.000000
# 50%              1628.000000              0.000000      378.000000
# 75%              6089.000000              0.000000     1209.000000
# max              9273.000000            627.000000     2976.000000
#
#        negativeIncrease  onVentilatorCurrently      positive  \
# count             299.0             299.000000  2.990000e+02
# mean                0.0             455.581940  6.632892e+05
# std                 0.0             478.763132  3.843383e+05
# min                 0.0              47.000000  3.274690e+05
# 25%                 0.0              82.500000  4.077535e+05
# 50%                 0.0             212.000000  4.633600e+05
# 75%                 0.0             796.500000  8.100120e+05
# max                 0.0            2425.000000  1.636680e+06
#
#        positiveIncrease  positiveScore  totalTestEncountersViral  \
# count        299.000000          299.0              2.990000e+02
# mean        4390.307692            0.0              1.435444e+07
# std         4803.051227            0.0              1.080926e+07
# min          391.000000            0.0              1.089916e+06
# 25%          747.500000            0.0              5.197896e+06
# 50%         1598.000000            0.0              1.111029e+07
# 75%         7779.000000            0.0              2.257866e+07
# max        19942.000000            0.0              3.828107e+07
#
#        totalTestEncountersViralIncrease  totalTestResults  \
# count                        299.000000      2.990000e+02
# mean                      124498.836120      1.435444e+07
# std                        69600.538023      1.080926e+07
# min                        20463.000000      1.089916e+06
# 25%                        66316.500000      5.197896e+06
# 50%                        99761.000000      1.111029e+07
# 75%                       175894.000000      2.257866e+07
# max                       324671.000000      3.828107e+07
#
#        totalTestResultsIncrease  totalTestsPeopleViralIncrease  \
# count                299.000000                          299.0
# mean              124498.836120                            0.0
# std                69600.538023                            0.0
# min                20463.000000                            0.0
# 25%                66316.500000                            0.0
# 50%                99761.000000                            0.0
# 75%               175894.000000                            0.0
# max               324671.000000                            0.0
#
#        totalTestsViralIncrease
# count                    299.0
# mean                       0.0
# std                        0.0
# min                        0.0
# 25%                        0.0
# 50%                        0.0
# 75%                        0.0
# max                        0.0

# %% [markdown]
# The table shows deaths have mean and std of 27,321 and 4166 respectively. These are very interesting figures that makes us interested in understanding the deaths more. # Handle date time conversions between pandas and matplotlib
# from pandas.plotting import register_matplotlib_converters
# register_matplotlib_converters()Let's continue with an exploration of number of deaths from Covid-19 in New York

# %%
plt.figure(figsize=(10,10))
plt.plot(df3.index.values,df3['death'])
plt.title('Number of Deaths over Time')
plt.xlabel('Date')
plt.ylabel('Number of deaths')
# Rotate tick marks on x-axis
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# A sharp increase in number of deaths is observed from march 2020 to around April 2020 and then a gradual rise until late june. This is followed by a  constant daily death rate between July and late October 2020. Subsequently, a rise is observed from november 2020 to march 2021. We observe that there are two types of trends in the date rate in New York. A increase and static.
#
# Let's view the distribution of the deaths to gain more insight into covid-19 deaths in new york

# %%
plt.figure(figsize=(8,8))
plt.title('Distribution of deaths from Covid-19 in New York')
sns.histplot(df3['death'],bins=25,kde="True")
plt.show()

# %% [markdown]
# The hsitogram shows a right skewed (positively) distribution. This is confrimed with the mean > median.

# %% [markdown]
# #### Numerical Columns
#
# Let's Plot the columns with numerical values only to view their distributions. Only date and state will be exempted from this subset.
#
# More discussions on these will ensue next time

# %%
list(df2.dtypes.tolist()) #view the datatypes present in the dataset
# Out:
# [dtype('<M8[ns]'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64')]

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#      death  deathConfirmed  deathIncrease  deathProbable  hospitalized  \
# 0  38577.0             NaN             80            NaN       89995.0
# 1  38497.0             NaN             90            NaN       89995.0
# 2  38407.0             NaN             86            NaN       89995.0
# 3  38321.0             NaN             94            NaN       89995.0
# 4  38227.0             NaN             92            NaN       89995.0
#
#    hospitalizedCumulative  hospitalizedCurrently  hospitalizedIncrease  \
# 0                 89995.0                 5307.0                     0
# 1                 89995.0                 5259.0                     0
# 2                 89995.0                 5445.0                     0
# 3                 89995.0                 5626.0                     0
# 4                 89995.0                 5703.0                     0
#
#    inIcuCumulative  inIcuCurrently  ...  totalTestResults  \
# 0              NaN          1065.0  ...          38281073
# 1              NaN          1083.0  ...          38106915
# 2              NaN          1121.0  ...          37833195
# 3              NaN          1132.0  ...          37547888
# 4              NaN          1124.0  ...          37256699
#
#    totalTestResultsIncrease  totalTestsAntibody  totalTestsAntigen  \
# 0                    174158                 NaN                NaN
# 1                    273720                 NaN                NaN
# 2                    285307                 NaN                NaN
# 3                    291189                 NaN                NaN
# 4                    278942                 NaN                NaN
#
#    totalTestsPeopleAntibody  totalTestsPeopleAntigen  totalTestsPeopleViral  \
# 0                       NaN                      NaN                    NaN
# 1                       NaN                      NaN                    NaN
# 2                       NaN                      NaN                    NaN
# 3                       NaN                      NaN                    NaN
# 4                       NaN                      NaN                    NaN
#
#    totalTestsPeopleViralIncrease  totalTestsViral  totalTestsViralIncrease
# 0                              0              NaN                        0
# 1                              0              NaN                        0
# 2                              0              NaN                        0
# 3                              0              NaN                        0
# 4                              0              NaN                        0
#
# [5 rows x 39 columns]

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %% [markdown]
# ## Sources
#
# - [What is Data Analytics?](https://www.mastersindatascience.org/learning/what-is-data-analytics/)
# - [A beginners guide to data science pipelin](https://towardsdatascience.com/a-beginners-guide-to-the-data-science-pipeline-a4904b2d8ad3)
# - [Exploratory Data Analysis](https://www.ibm.com/cloud/learn/exploratory-data-analysis)
